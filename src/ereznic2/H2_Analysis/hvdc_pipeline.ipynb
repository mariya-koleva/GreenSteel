# %%
# %load_ext autoreload
# %autoreload 2

from length_revised import MVAC_vs_Pipeline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
l = MVAC_vs_Pipeline()

# %%
16*11
# Out:
# 176

# %%
pipeline_info = l.get_pipe_arm_lengths()
# Out:
# Estimating MN and _Grid
# Estimating MN and
# Estimating IN and _Grid
# Estimating IN and
# Estimating TX and _Grid
# Estimating TX and
# Estimating MS and _Grid
# Estimating MS and
# Estimating IA and _Grid
# Estimating IA and

# %%
pipeline_info.to_csv("Pipeline_info.csv")

# %%
pipeline_info
# Out:
#     Length of Pipe in Arm (m)  Number of such pipes needed  \
# 0                 3570.000000                         20.0
# 1                 6090.460447                          4.0
# 2                 4165.000000                          2.0
# 3                 5950.000000                         36.0
# 4                10361.457070                          4.0
# 5                    0.000000                          0.0
# 6                 3570.000000                         20.0
# 7                 6090.460447                          4.0
# 8                 4165.000000                          2.0
# 9                 5950.000000                         36.0
# 10               10361.457070                          4.0
# 11                   0.000000                          0.0
# 12                3570.000000                         20.0
# 13                6090.460447                          4.0
# 14                4165.000000                          2.0
# ...

# %%
l.compute_ampacity()
# Out:
# ------------------Finding ampacity of MN_Grid-------------------
# ------------------Finding ampacity of MN-------------------
# ------------------Finding ampacity of IN_Grid-------------------
# ------------------Finding ampacity of IN-------------------
# ------------------Finding ampacity of TX_Grid-------------------
# ------------------Finding ampacity of TX-------------------
# ------------------Finding ampacity of MS_Grid-------------------
# ------------------Finding ampacity of MS-------------------
# ------------------Finding ampacity of IA_Grid-------------------
# ------------------Finding ampacity of IA-------------------

# %%
k = l.pipeline_vs_cable_costs()
# Out:
# Finding material costs for MN_Grid farm
# Finding material costs for MN farm
# Finding material costs for IN_Grid farm
# Finding material costs for IN farm
# Finding material costs for TX_Grid farm
# Finding material costs for TX farm
# Finding material costs for MS_Grid farm
# Finding material costs for MS farm
# Finding material costs for IA_Grid farm
# Finding material costs for IA farm
# {'MN_Grid': [22252018.03161422], 'MN': [66955045.90970355], 'IN_Grid': [22252018.03161422], 'IN': [66955045.90970355], 'TX_Grid': [22252018.03161422], 'TX': [50196586.25992842], 'MS_Grid': [25655267.848214045], 'MS': [108416091.01790532], 'IA_Grid': [17232779.4457041], 'IA': [55183960.86188023]}

# %%
k.to_csv("cable_costs.csv")

# %%
k
# Out:
#         MN_Grid            MN       IN_Grid            IN       TX_Grid  \
# 0  2.225202e+07  6.695505e+07  2.225202e+07  6.695505e+07  2.225202e+07
#
#              TX       MS_Grid            MS       IA_Grid            IA
# 0  5.019659e+07  2.565527e+07  1.084161e+08  1.723278e+07  5.518396e+07
